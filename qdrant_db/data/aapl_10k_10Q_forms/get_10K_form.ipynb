# %%
import os
from dotenv import load_dotenv
from sec_api import QueryApi, RenderApi
# Load environment variables from .env file
load_dotenv()

# Retrieve the API key from the environment
QUERY_API_KEY = os.getenv("QUERY_API_KEY")
RENDER_API_KEY = os.getenv("RENDER_API_KEY")
# print(f"QUERY_API_KEY: {QUERY_API_KEY}")

# Initialize API clients
queryApi = QueryApi(api_key=QUERY_API_KEY)
renderApi = RenderApi(api_key=RENDER_API_KEY)

query = {
  "query": { "query_string": { 
      "query": "formType:\"10-K\" AND ticker:AAPL", # only 10-Ks
  }},
  "from": "0", # start returning matches from position null, i.e. the first matching filing 
  "size": "1"  # return just one filing
}

response = queryApi.get_filings(query)

# %%
import json 
print(json.dumps(response, indent=2))
# Out:
# {
#   "total": {
#     "value": 96,
#     "relation": "eq"
#   },
#   "query": {
#     "from": 0,
#     "size": 10
#   },
#   "filings": [
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-25-000008",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/aapl-20241228.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/0000320193-25-000008.txt",
#       "filedAt": "2025-01-31T06:01:27-05:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "732589",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019325000008/aapl-20241228.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "71323",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/a10-qexhibit10112282024.htm",
#           "description": "EX-10.1",
#           "type": "EX-10.1"
#         },
#         {
#           "sequence": "3",
#           "size": "82509",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/a10-qexhibit10212282024.htm",
#           "description": "EX-10.2",
#           "type": "EX-10.2"
#         },
#         {
#           "sequence": "4",
#           "size": "10529",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/a10-qexhibit31112282024.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "5",
#           "size": "10568",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/a10-qexhibit31212282024.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "6",
#           "size": "8372",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/a10-qexhibit32112282024.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "12",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/aapl-20241228_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "13",
#           "size": "3431",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/image_0.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "5150277",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/0000320193-25-000008.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2024-12-28",
#       "entities": [
#         {
#           "fiscalYearEnd": "0927",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "25575705",
#           "undefined": "06 Technology)"
#         }
#       ],
#       "id": "87ad46d753be2052b74aaeb653c43dc0",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/0000320193-25-000008-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "7",
#           "size": "34533",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/aapl-20241228.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "8",
#           "size": "75630",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/aapl-20241228_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "9",
#           "size": "155214",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/aapl-20241228_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "10",
#           "size": "497582",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/aapl-20241228_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "11",
#           "size": "318265",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/aapl-20241228_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "66",
#           "size": "641761",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019325000008/aapl-20241228_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-24-000081",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081.txt",
#       "filedAt": "2024-08-01T18:03:34-04:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "889136",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000081/aapl-20240629.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "10527",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit31106292024.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "3",
#           "size": "10544",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit31206292024.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "4",
#           "size": "8338",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit32106292024.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "10",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "5372771",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2024-06-29",
#       "entities": [
#         {
#           "fiscalYearEnd": "0928",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "241168182",
#           "undefined": "06 Technology)"
#         }
#       ],
#       "id": "cf8f0e4b9c36b768706ac2f63dfceb84",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "5",
#           "size": "34455",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "6",
#           "size": "79020",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "7",
#           "size": "155463",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "8",
#           "size": "496189",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "9",
#           "size": "320486",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "69",
#           "size": "786618",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-24-000069",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069.txt",
#       "filedAt": "2024-05-02T18:04:25-04:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "884846",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000069/aapl-20240330.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "10524",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit31103302024.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "3",
#           "size": "10541",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit31203302024.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "4",
#           "size": "8334",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit32103302024.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "10",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "5284139",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2024-03-30",
#       "entities": [
#         {
#           "fiscalYearEnd": "0928",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "24910117",
#           "undefined": "06 Technology)"
#         }
#       ],
#       "id": "6c0b495bc8a221cf32387c0123aeee5a",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "5",
#           "size": "32774",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "6",
#           "size": "79020",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "7",
#           "size": "150723",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "8",
#           "size": "486518",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "9",
#           "size": "313675",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "68",
#           "size": "780999",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-24-000006",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006.txt",
#       "filedAt": "2024-02-01T18:03:38-05:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "732173",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000006/aapl-20231230.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "10529",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit31112302023.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "3",
#           "size": "10546",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit31212302023.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "4",
#           "size": "8350",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit32112302023.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "10",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "4984121",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2023-12-30",
#       "entities": [
#         {
#           "fiscalYearEnd": "0928",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "24588164"
#         }
#       ],
#       "id": "89bd0dd65bb737638cd64a2f597b5155",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "5",
#           "size": "33359",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "6",
#           "size": "79020",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "7",
#           "size": "151992",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "8",
#           "size": "534119",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "9",
#           "size": "315230",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "67",
#           "size": "666167",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-23-000077",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/aapl-20230701.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/0000320193-23-000077.txt",
#       "filedAt": "2023-08-03T18:04:43-04:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "963209",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019323000077/aapl-20230701.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "10527",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/a10-qexhibit31107012023.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "3",
#           "size": "10544",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/a10-qexhibit31207012023.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "4",
#           "size": "8336",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/a10-qexhibit32107012023.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "10",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/aapl-20230701_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "5939898",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/0000320193-23-000077.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2023-07-01",
#       "entities": [
#         {
#           "fiscalYearEnd": "0930",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "231141522"
#         }
#       ],
#       "id": "7110f6ab331243b8cf7387dcbdd90ab4",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/0000320193-23-000077-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "5",
#           "size": "38069",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/aapl-20230701.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "6",
#           "size": "87387",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/aapl-20230701_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "7",
#           "size": "178610",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/aapl-20230701_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "8",
#           "size": "588481",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/aapl-20230701_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "9",
#           "size": "354445",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/aapl-20230701_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "63",
#           "size": "892947",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/aapl-20230701_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-23-000064",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/aapl-20230401.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/0000320193-23-000064.txt",
#       "filedAt": "2023-05-04T18:03:52-04:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "1279490",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019323000064/aapl-20230401.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "10626",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/a10-qexhibit31104012023.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "3",
#           "size": "10643",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/a10-qexhibit31204012023.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "4",
#           "size": "8434",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/a10-qexhibit32104012023.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "10",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/aapl-20230401_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "6314786",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/0000320193-23-000064.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2023-04-01",
#       "entities": [
#         {
#           "fiscalYearEnd": "0930",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "23890444"
#         }
#       ],
#       "id": "fb882bd594c2e70288b490d692759027",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/0000320193-23-000064-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "5",
#           "size": "38442",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/aapl-20230401.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "6",
#           "size": "86806",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/aapl-20230401_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "7",
#           "size": "181210",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/aapl-20230401_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "8",
#           "size": "505230",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/aapl-20230401_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "9",
#           "size": "312183",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/aapl-20230401_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "61",
#           "size": "1205740",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/aapl-20230401_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-23-000006",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/aapl-20221231.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/0000320193-23-000006.txt",
#       "filedAt": "2023-02-02T18:01:30-05:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "1058932",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019323000006/aapl-20221231.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "57467",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/a10-qexhibit10112312022.htm",
#           "description": "EX-10.1",
#           "type": "EX-10.1"
#         },
#         {
#           "sequence": "3",
#           "size": "72044",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/a10-qexhibit10212312022.htm",
#           "description": "EX-10.2",
#           "type": "EX-10.2"
#         },
#         {
#           "sequence": "4",
#           "size": "10631",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/a10-qexhibit31112312022.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "5",
#           "size": "10648",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/a10-qexhibit31212312022.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "6",
#           "size": "8452",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/a10-qexhibit32112312022.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "12",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/aapl-20221231_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "5915088",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/0000320193-23-000006.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2022-12-31",
#       "entities": [
#         {
#           "fiscalYearEnd": "0930",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "23582662"
#         }
#       ],
#       "id": "b6b38397ff01dcb8f1dab18145f8e699",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/0000320193-23-000006-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "7",
#           "size": "37206",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/aapl-20221231.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "8",
#           "size": "89182",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/aapl-20221231_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "9",
#           "size": "177689",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/aapl-20221231_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "10",
#           "size": "500457",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/aapl-20221231_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "11",
#           "size": "310025",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/aapl-20221231_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "61",
#           "size": "1015851",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/aapl-20221231_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-22-000070",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/0000320193-22-000070.txt",
#       "filedAt": "2022-07-28T18:06:56-04:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "1295660",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019322000070/aapl-20220625.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "10628",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/a10-qexhibit31106252022.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "3",
#           "size": "10645",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/a10-qexhibit31206252022.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "4",
#           "size": "8438",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/a10-qexhibit32106252022.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "10",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "6109993",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/0000320193-22-000070.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2022-06-25",
#       "entities": [
#         {
#           "fiscalYearEnd": "0924",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "221116600"
#         }
#       ],
#       "id": "f4a5a168926141e94227e90c96c4bc2d",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/0000320193-22-000070-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "5",
#           "size": "35163",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "6",
#           "size": "85165",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "7",
#           "size": "157188",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "8",
#           "size": "472026",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "9",
#           "size": "287390",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "57",
#           "size": "1203313",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/aapl-20220625_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-22-000059",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/0000320193-22-000059.txt",
#       "filedAt": "2022-04-28T18:03:58-04:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "1310405",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019322000059/aapl-20220326.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "10629",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/a10-qexhibit31103262022.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "3",
#           "size": "10646",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/a10-qexhibit31203262022.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "4",
#           "size": "8442",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/a10-qexhibit32103262022.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "10",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "6140838",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/0000320193-22-000059.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2022-03-26",
#       "entities": [
#         {
#           "fiscalYearEnd": "0924",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "22868650"
#         }
#       ],
#       "id": "bbfd7991fe77c202ccd6583656b8eda2",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/0000320193-22-000059-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "5",
#           "size": "35163",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "6",
#           "size": "85165",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "7",
#           "size": "157188",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "8",
#           "size": "472033",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "9",
#           "size": "287390",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "57",
#           "size": "1214261",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/aapl-20220326_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     },
#     {
#       "ticker": "AAPL",
#       "formType": "10-Q",
#       "accessionNo": "0000320193-22-000007",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225.htm",
#       "description": "Form 10-Q - Quarterly report [Sections 13 or 15(d)]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/0000320193-22-000007.txt",
#       "filedAt": "2022-01-27T18:00:58-05:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "1064578",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019322000007/aapl-20211225.htm",
#           "description": "10-Q",
#           "type": "10-Q"
#         },
#         {
#           "sequence": "2",
#           "size": "82707",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/a10-qexhibit10112252021.htm",
#           "description": "EX-10.1",
#           "type": "EX-10.1"
#         },
#         {
#           "sequence": "3",
#           "size": "10631",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/a10-qexhibit31112252021.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "4",
#           "size": "10648",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/a10-qexhibit31212252021.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "5",
#           "size": "8452",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/a10-qexhibit32112252021.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "11",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "5669748",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/0000320193-22-000007.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2021-12-25",
#       "entities": [
#         {
#           "fiscalYearEnd": "0924",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-Q",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "22564628"
#         }
#       ],
#       "id": "7db4a24a11f907eba3628b6b9731238c",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/0000320193-22-000007-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "6",
#           "size": "35964",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "7",
#           "size": "85131",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "8",
#           "size": "159406",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "9",
#           "size": "478019",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "10",
#           "size": "289806",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "58",
#           "size": "1005847",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/aapl-20211225_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     }
#   ]
# }

# %%
# Base query template
base_query = {
  "query": { 
      "query_string": { 
          "query": "PLACEHOLDER",  # Placeholder to be replaced by the specific query
          "time_zone": "America/New_York"
      } 
  },
  "from": "0",
  "size": "200",
  # sort returned filings by the filedAt key/value
  "sort": [{"filedAt": {"order": "desc"}}]
}

# Open the file we use to store the filing URLs
log_file = open("filing_urls_AAPL.txt", "a")

# Fetch filings for years 2022 and 2021
for year in range(2022, 2025, 1):
    print(f"Starting download for year {year}")
    
    for month in range(1, 13, 1):  # Iterate over each month
        # Construct search query for 10-K filings within the given year-month for AAPL
        universe_query = (
            "formType:(\"10-K\") AND " +
            "filedAt:[{year}-{month:02d}-01 TO {year}-{month:02d}-31] AND " +
            "ticker:AAPL"
        ).format(year=year, month=month)

        # Debugging: Print the query being generated
        print(f"Generated query: {universe_query}")

        # Update query template with specific query string
        base_query["query"]["query_string"]["query"] = universe_query

        # Pagination: Fetch results in batches of 200
        for from_batch in range(0, 400, 200):  # Update pagination start index 
            base_query["from"] = from_batch

            # Debugging: Print the page we're fetching
            print(f"Fetching batch starting at index {from_batch}...")

            try:
                response = queryApi.get_filings(base_query)
                
                # Debugging: Print the raw response
                print(f"Response received: {response}")

                # Stop if no more filings are found
                if len(response["filings"]) == 0:
                    print("No more filings found.")
                    break

                # Extract and store filing URLs
                urls_list = [x["linkToFilingDetails"] for x in response["filings"]]

                # Debugging: Print the number of URLs found in this batch
                print(f"Found {len(urls_list)} URLs in this batch")

                # Transform list of URLs into one string by joining all list elements
                # and add a new-line character between each element.
                urls_string = "\n".join(urls_list) + "\n"
                
                # Write URLs to log file
                log_file.write(urls_string)

            except Exception as e:
                print(f"Error during API request: {e}")
                break

# Close the log file
log_file.close()
print("All AAPL URLs downloaded")
# Out:
# Starting download for year 2022
# Generated query: formType:("10-K") AND filedAt:[2022-01-01 TO 2022-01-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-02-01 TO 2022-02-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-03-01 TO 2022-03-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-04-01 TO 2022-04-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-05-01 TO 2022-05-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-06-01 TO 2022-06-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-07-01 TO 2022-07-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-08-01 TO 2022-08-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-09-01 TO 2022-09-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-10-01 TO 2022-10-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-K', 'accessionNo': '0000320193-22-000108', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm', 'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108.txt', 'filedAt': '2022-10-27T18:01:14-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '2049857', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm', 'description': '10-K', 'type': '10-K'}, {'sequence': '2', 'size': '124132', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit4109242022.htm', 'description': 'EX-4.1', 'type': 'EX-4.1'}, {'sequence': '3', 'size': '11827', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit21109242022.htm', 'description': 'EX-21.1', 'type': 'EX-21.1'}, {'sequence': '4', 'size': '6073', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit23109242022.htm', 'description': 'EX-23.1', 'type': 'EX-23.1'}, {'sequence': '5', 'size': '10609', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit31109242022.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '6', 'size': '10645', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit31209242022.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '7', 'size': '8458', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit32109242022.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '13', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '14', 'size': '165673', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_g2.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '10332356', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfReport': '2022-09-24', 'entities': [{'fiscalYearEnd': '0924', 'stateOfIncorporation': 'CA', 'act': '34', 'cik': '320193', 'fileNo': '001-36743', 'irsNo': '942404110', 'companyName': 'Apple Inc. (Filer)', 'type': '10-K', 'sic': '3571 Electronic Computers', 'filmNo': '221338448'}], 'id': '9b58a0b3d70dc9de06bdf3d560b3317a', 'seriesAndClassesContractsInformation': [], 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108-index.htm', 'linkToXbrl': '', 'dataFiles': [{'sequence': '8', 'size': '58100', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.xsd', 'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT', 'type': 'EX-101.SCH'}, {'sequence': '9', 'size': '149987', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_cal.xml', 'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT', 'type': 'EX-101.CAL'}, {'sequence': '10', 'size': '252038', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_def.xml', 'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT', 'type': 'EX-101.DEF'}, {'sequence': '11', 'size': '783084', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_lab.xml', 'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT', 'type': 'EX-101.LAB'}, {'sequence': '12', 'size': '478290' ...
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-11-01 TO 2022-11-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-12-01 TO 2022-12-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Starting download for year 2023
# Generated query: formType:("10-K") AND filedAt:[2023-01-01 TO 2023-01-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-02-01 TO 2023-02-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-03-01 TO 2023-03-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-04-01 TO 2023-04-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-05-01 TO 2023-05-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-06-01 TO 2023-06-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-07-01 TO 2023-07-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-08-01 TO 2023-08-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-09-01 TO 2023-09-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-10-01 TO 2023-10-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-11-01 TO 2023-11-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-K', 'accessionNo': '0000320193-23-000106', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930.htm', 'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106.txt', 'filedAt': '2023-11-02T18:08:27-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '1558924', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019323000106/aapl-20230930.htm', 'description': '10-K', 'type': '10-K'}, {'sequence': '2', 'size': '121966', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit4109302023.htm', 'description': 'EX-4.1', 'type': 'EX-4.1'}, {'sequence': '3', 'size': '11229', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit21109302023.htm', 'description': 'EX-21.1', 'type': 'EX-21.1'}, {'sequence': '4', 'size': '5451', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit23109302023.htm', 'description': 'EX-23.1', 'type': 'EX-23.1'}, {'sequence': '5', 'size': '10507', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit31109302023.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '6', 'size': '10543', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit31209302023.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '7', 'size': '8356', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit32109302023.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '13', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '14', 'size': '146631', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_g2.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '9569569', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfReport': '2023-09-30', 'entities': [{'fiscalYearEnd': '0930', 'stateOfIncorporation': 'CA', 'act': '34', 'cik': '320193', 'fileNo': '001-36743', 'irsNo': '942404110', 'companyName': 'Apple Inc. (Filer)', 'type': '10-K', 'sic': '3571 Electronic Computers', 'filmNo': '231373899'}], 'id': '0de409aa5047085970060a9efa218f8b', 'seriesAndClassesContractsInformation': [], 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106-index.htm', 'linkToXbrl': '', 'dataFiles': [{'sequence': '8', 'size': '59730', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930.xsd', 'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT', 'type': 'EX-101.SCH'}, {'sequence': '9', 'size': '155393', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_cal.xml', 'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT', 'type': 'EX-101.CAL'}, {'sequence': '10', 'size': '233471', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_def.xml', 'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT', 'type': 'EX-101.DEF'}, {'sequence': '11', 'size': '854271', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_lab.xml', 'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT', 'type': 'EX-101.LAB'}, {'sequence': '12', 'size': '516226', ...
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-12-01 TO 2023-12-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Starting download for year 2024
# Generated query: formType:("10-K") AND filedAt:[2024-01-01 TO 2024-01-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-02-01 TO 2024-02-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-03-01 TO 2024-03-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-04-01 TO 2024-04-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-05-01 TO 2024-05-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-06-01 TO 2024-06-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-07-01 TO 2024-07-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-08-01 TO 2024-08-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-09-01 TO 2024-09-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-10-01 TO 2024-10-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-11-01 TO 2024-11-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-K', 'accessionNo': '0000320193-24-000123', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm', 'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123.txt', 'filedAt': '2024-11-01T06:01:36-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '1503780', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm', 'description': '10-K', 'type': '10-K'}, {'sequence': '2', 'size': '120785', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit4109282024.htm', 'description': 'EX-4.1', 'type': 'EX-4.1'}, {'sequence': '3', 'size': '56948', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10199282024.htm', 'description': 'EX-10.19', 'type': 'EX-10.19'}, {'sequence': '4', 'size': '74591', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10209282024.htm', 'description': 'EX-10.20', 'type': 'EX-10.20'}, {'sequence': '5', 'size': '60845', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10219282024.htm', 'description': 'EX-10.21', 'type': 'EX-10.21'}, {'sequence': '6', 'size': '75240', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10229282024.htm', 'description': 'EX-10.22', 'type': 'EX-10.22'}, {'sequence': '7', 'size': '44108', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit1919282024.htm', 'description': 'EX-19.1', 'type': 'EX-19.1'}, {'sequence': '8', 'size': '11229', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit21109282024.htm', 'description': 'EX-21.1', 'type': 'EX-21.1'}, {'sequence': '9', 'size': '5018', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit23109282024.htm', 'description': 'EX-23.1', 'type': 'EX-23.1'}, {'sequence': '10', 'size': '10508', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit31109282024.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '11', 'size': '10544', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit31209282024.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '12', 'size': '8357', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit32109282024.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '13', 'size': '13555', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit97109282024.htm', 'description': 'EX-97.1', 'type': 'EX-97.1'}, {'sequence': '19', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '20', 'size': '154498', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_g2.jpg', 'type': 'GRAPHIC'}, {'sequence': '21', 'size': '2374', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/image_0.jpg', 'type': 'GRAPHIC'}, {'sequence': '22', 'size': '2563', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/image_01.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '9759333', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfR ...
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-12-01 TO 2024-12-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# All AAPL URLs downloaded

# %%
import multiprocessing

# Download 10-k Filings from Stored URLs
def download_filing(url):
  """
  Downloads a 10-K filing from SEC-API and saves it to the 'filings' folder.
  """
  filing = renderApi.get_filing(url)
  file_name = url.split("/")[-2] + "-" + url.split("/")[-1] # Generate filename
  download_to = "./filings/" + file_name
  
  with open(download_to, "w") as f:
    f.write(filing) # Save filing content to file


# load URLs from log file
def load_urls():
  """
  Loads filing URLs from the log file.
  Returns a list of URLs.
  """
  log_file = open("filing_urls_AAPL.txt", "r")
  urls = log_file.read().split("\n") # convert long string of URLs into a list 
  log_file.close()
  return urls

def download_all_filings():
  """
  Downloads all filings in parallel using multiprocessing.
  """
  print("Start downloading all filings")

  # Create download folder if it doesn't exist
  download_folder = "./filings" 
  if not os.path.isdir(download_folder):
    os.makedirs(download_folder)
    
# Load filing URLs
  urls = load_urls()[1:40] # Downloading the first 40 for testing
  print("{length} filing URLs loaded".format(length=len(urls)))

  # Number of parallel processes for downloading
  number_of_processes = 20

  with multiprocessing.Pool(number_of_processes) as pool:
    pool.map(download_filing, urls)
  
  print("All filings downloaded")

# %%
# Execute download process
download_all_filings()
