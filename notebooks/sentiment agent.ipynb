# %%
from qdrant_client import QdrantClient

# Connect to local Qdrant instance
client = QdrantClient(url="http://localhost:6333")

# Check if the collection exists
collections = client.get_collections()
print(collections)

# Load data from the `financial_news` collection
collection_name = "financial_news"
collection_info = client.get_collection(collection_name)
print(collection_info)
# Out:
# collections=[CollectionDescription(name='earnings_calls'), CollectionDescription(name='aapl_10k_10q_forms'), CollectionDescription(name='financial_news')]
# status=<CollectionStatus.GREEN: 'green'> optimizer_status=<OptimizersStatusOneOf.OK: 'ok'> vectors_count=None indexed_vectors_count=0 points_count=96 segments_count=4 config=CollectionConfig(params=CollectionParams(vectors=VectorParams(size=1024, distance=<Distance.COSINE: 'Cosine'>, hnsw_config=None, quantization_config=None, on_disk=None, datatype=None, multivector_config=None), shard_number=1, sharding_method=None, replication_factor=1, write_consistency_factor=1, read_fan_out_factor=None, on_disk_payload=True, sparse_vectors=None), hnsw_config=HnswConfig(m=16, ef_construct=100, full_scan_threshold=10000, max_indexing_threads=0, on_disk=False, payload_m=None), optimizer_config=OptimizersConfig(deleted_threshold=0.2, vacuum_min_vector_number=1000, default_segment_number=0, max_segment_size=None, memmap_threshold=None, indexing_threshold=20000, flush_interval_sec=5, max_optimization_threads=None), wal_config=WalConfig(wal_capacity_mb=32, wal_segments_ahead=0), quantization_config=None, strict_mode_config=StrictModeConfig(enabled=False, max_query_limit=None, max_timeout=None, unindexed_filtering_retrieve=None, unindexed_filtering_update=None, search_max_hnsw_ef=None, search_allow_exact=None, search_max_oversampling=None, upsert_max_batchsize=None, max_collection_vector_size_bytes=None, read_rate_limit=None, write_rate_limit=None, max_collection_payload_size_bytes=None, filter_max_conditions=None, condition_max_size=None)) payload_schema={}

# %%
from qdrant_client.http.models import PointRequest

# Retrieve the first 5 points
points = client.scroll(collection_name="financial_news", limit=5)

print(points)
# Out:
# ([Record(id=5813337049586389, payload={'document': 'Apple (NASDAQ: AAPL) stock has experienced many struggles since its 1980 IPO. After its board fired Steve Jobs in 1985, the company spent years in the wilderness. It suspended its dividend payout in 1996, and was close to bankruptcy when it brought Jobs back in 1997.', 'file_name': "If You'd Invested $1,000 in Apple Stock 27 Years Ago, Here's How Much You'd Have Today.txt", 'chunk_index': 0, 'title': "If You'd Invested $1,000 in Apple Stock 27 Years Ago, Here's How Much You'd Have Today", 'source': 'finance.yahoo.com', 'summary': 'Apple (NASDAQ: AAPL) stock has experienced many struggles since its 1980 IPO. After its board fired Steve Jobs in 1985, the company spent years in the wilderness. It suspended its dividend payout in 1...', 'publish_date': '2024-06-28T22:32:07.000Z', 'url': 'https://finance.yahoo.com/news/youd-invested-1-000-apple-223207115.html'}, vector=None, shard_key=None, order_value=None), Record(id=10631151568077030, payload={'document': 'Billionaire Jeff Bezos is throwing his weight behind a computing company that’s coming for Nvidia’s (NVDA) dominance of the artificial intelligence chip market.', 'file_name': 'Jeff Bezos is betting millions on a Nvidia rival.txt', 'chunk_index': 0, 'title': 'Jeff Bezos is betting millions on a Nvidia rival', 'source': 'www.yahoo.com', 'summary': 'Billionaire Jeff Bezos is throwing his weight behind a computing company that’s coming for Nvidia’s (NVDA) dominance of the artificial intelligence chip market.', 'publish_date': '2024-12-02T13:37:00.000Z', 'url': 'https://www.yahoo.com/tech/jeff-bezos-betting-millions-nvidia-133700975.html'}, vector=None, shard_key=None, order_value=None), Record(id=116734477794576535, payload={'document': 'US stock futures stalled on Tuesday as investors trod carefully on the eve of a closely watched consumer inflation report seen as key to the path of interest rates.', 'file_name': 'Stock market today: Dow, S&P 500, Nasdaq futures hit pause in countdown to consumer inflation data.txt', 'chunk_index': 0, 'title': 'Stock market today: Dow, S&P 500, Nasdaq futures hit pause in countdown to consumer inflation data', 'source': 'finance.yahoo.com', 'summary': 'US stock futures stalled on Tuesday as investors trod carefully on the eve of a closely watched consumer inflation report seen as key to the path of interest rates.', 'publish_date': '2024-12-10T12:13:38.000Z', 'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-futures-hit-pause-in-countdown-to-consumer-inflation-data-121338558.html'}, vector=None, shard_key=None, order_value=None), Record(id=198279485335112738, payload={'document': 'There\'s arguably not a billionaire money manager that garners more attention on Wall Street than Berkshire Hathaway\'s (NYSE: BRK.A)(NYSE: BRK.B) chief, Warren Buffett. The accurately dubbed "Oracle of Omaha" has led his company\'s Class A shares (BRK.A) to a mouthwatering aggregate return of more than 5,600,000% since he became CEO almost six decades ago.', 'file_name': "Billionaire Warren Buffett Sold 56% of Berkshire's Stake in Apple and Is Piling Into Wall Street's Most Prominent Reverse Stock Split of 2024.txt", 'chunk_index': 0, 'title': "Billionaire Warren Buffett Sold 56% of Berkshire's Stake in Apple and Is Piling Into Wall Street's Most Prominent Reverse Stock Split of 2024", 'source': 'finance.yahoo.com', 'summary': 'There\'s arguably not a billionaire money manager that garners more attention on Wall Street than Berkshire Hathaway\'s (NYSE: BRK.A)(NYSE: BRK.B) chief, Warren Buffett. The accurately dubbed "Oracle of...', 'publish_date': '2024-10-23T09:06:00.000Z', 'url': 'https://finance.yahoo.com/news/billionaire-warren-buffett-sold-56-090600109.html'}, vector=None, shard_key=None, order_value=None), Record(id=500922625662508676, payload={'document': 'Nvidia (NVDA) stock sank more than 2% early Tuesday as investors grew cautious that the AI spending that has fueled its rise  ...

# %%
# Retrieve 5 records from the collection
records, _ = client.scroll(collection_name="financial_news", limit=5)

# Print formatted output
for record in records:
    print(f"Title: {record.payload.get('title')}")
    print(f"Source: {record.payload.get('source')}")
    print(f"Publish Date: {record.payload.get('publish_date')}")
    print(f"URL: {record.payload.get('url')}")
    print(f"Summary: {record.payload.get('summary')}\n")
    print("="*80)
# Out:
# Title: If You'd Invested $1,000 in Apple Stock 27 Years Ago, Here's How Much You'd Have Today
# Source: finance.yahoo.com
# Publish Date: 2024-06-28T22:32:07.000Z
# URL: https://finance.yahoo.com/news/youd-invested-1-000-apple-223207115.html
# Summary: Apple (NASDAQ: AAPL) stock has experienced many struggles since its 1980 IPO. After its board fired Steve Jobs in 1985, the company spent years in the wilderness. It suspended its dividend payout in 1...
#
# ================================================================================
# Title: Jeff Bezos is betting millions on a Nvidia rival
# Source: www.yahoo.com
# Publish Date: 2024-12-02T13:37:00.000Z
# URL: https://www.yahoo.com/tech/jeff-bezos-betting-millions-nvidia-133700975.html
# Summary: Billionaire Jeff Bezos is throwing his weight behind a computing company that’s coming for Nvidia’s (NVDA) dominance of the artificial intelligence chip market.
#
# ================================================================================
# Title: Stock market today: Dow, S&P 500, Nasdaq futures hit pause in countdown to consumer inflation data
# Source: finance.yahoo.com
# Publish Date: 2024-12-10T12:13:38.000Z
# URL: https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-futures-hit-pause-in-countdown-to-consumer-inflation-data-121338558.html
# Summary: US stock futures stalled on Tuesday as investors trod carefully on the eve of a closely watched consumer inflation report seen as key to the path of interest rates.
#
# ================================================================================
# Title: Billionaire Warren Buffett Sold 56% of Berkshire's Stake in Apple and Is Piling Into Wall Street's Most Prominent Reverse Stock Split of 2024
# Source: finance.yahoo.com
# Publish Date: 2024-10-23T09:06:00.000Z
# URL: https://finance.yahoo.com/news/billionaire-warren-buffett-sold-56-090600109.html
# Summary: There's arguably not a billionaire money manager that garners more attention on Wall Street than Berkshire Hathaway's (NYSE: BRK.A)(NYSE: BRK.B) chief, Warren Buffett. The accurately dubbed "Oracle of...
#
# ================================================================================
# Title: Nvidia stock slides amid AI spending slowdown fears, increased competition
# Source: finance.yahoo.com
# Publish Date: 2024-12-17T14:56:36.000Z
# URL: https://finance.yahoo.com/news/nvidia-stock-slides-amid-ai-spending-slowdown-fears-increased-competition-145636549.html
# Summary: Nvidia (NVDA) stock sank more than 2% early Tuesday as investors grew cautious that the AI spending that has fueled its rise could ease or spread to rivals.
#
# ================================================================================

# %%
from transformers import pipeline
import torch

# Load FinBERT for sentiment analysis
sentiment_pipeline = pipeline("text-classification", model="ProsusAI/finbert", tokenizer="ProsusAI/finbert")

# Function to get sentiment and confidence scores
def analyze_sentiment(text):
    result = sentiment_pipeline(text, truncation=True, max_length=512)[0]  # Ensure text fits model limit
    return result["label"], result["score"]

# Retrieve all financial news records
all_records = []
offset = None
batch_size = 100  # Process in batches to handle large collections efficiently

while True:
    batch_records, next_offset = client.scroll(
        collection_name="financial_news",
        limit=batch_size,
        offset=offset,
        with_payload=True  # Need payload for sentiment analysis
    )
    
    if not batch_records:
        break
        
    all_records.extend(batch_records)
    
    if next_offset is None:
        break
        
    offset = next_offset

print(f"Retrieved {len(all_records)} records in total")

# Process records in batches to avoid overloading memory
batch_size = 20
for i in range(0, len(all_records), batch_size):
    batch = all_records[i:i+batch_size]
    
    # First, analyze sentiment for the batch
    for record in batch:
        text = record.payload.get("document", "")
        if text:
            sentiment, confidence = analyze_sentiment(text)
            
            # Create a new payload with just the sentiment fields
            sentiment_payload = {
                "sentiment": sentiment,
                "confidence_score": float(confidence)
            }
            
            # Update ONLY the sentiment fields in the database
            client.set_payload(
                collection_name="financial_news",
                payload=sentiment_payload,
                points=[record.id]
            )
    
    print(f"Processed batch {i//batch_size + 1}/{(len(all_records) + batch_size - 1)//batch_size}")

# Print updated results 
# Fetch the updated records to verify
updated_records, _ = client.scroll(
    collection_name="financial_news",
    limit=len(all_records),
    with_payload=True
)

for record in updated_records:
    print(f"Title: {record.payload.get('title')}")
    print(f"Sentiment: {record.payload.get('sentiment')} (Confidence: {record.payload.get('confidence_score', 0):.4f})")
    print(f"Summary: {record.payload.get('summary')}\n")
    print("="*80)

print(f"Updated sentiment analysis for {len(updated_records)} records")
# Out:
# Device set to use cpu
# Retrieved 96 records in total
# Processed batch 1/5
# Processed batch 2/5
# Processed batch 3/5
# Processed batch 4/5
# Processed batch 5/5
# Title: If You'd Invested $1,000 in Apple Stock 27 Years Ago, Here's How Much You'd Have Today
# Sentiment: negative (Confidence: 0.9497)
# Summary: Apple (NASDAQ: AAPL) stock has experienced many struggles since its 1980 IPO. After its board fired Steve Jobs in 1985, the company spent years in the wilderness. It suspended its dividend payout in 1...
#
# ================================================================================
# Title: Jeff Bezos is betting millions on a Nvidia rival
# Sentiment: neutral (Confidence: 0.9108)
# Summary: Billionaire Jeff Bezos is throwing his weight behind a computing company that’s coming for Nvidia’s (NVDA) dominance of the artificial intelligence chip market.
#
# ================================================================================
# Title: Stock market today: Dow, S&P 500, Nasdaq futures hit pause in countdown to consumer inflation data
# Sentiment: negative (Confidence: 0.9630)
# Summary: US stock futures stalled on Tuesday as investors trod carefully on the eve of a closely watched consumer inflation report seen as key to the path of interest rates.
#
# ================================================================================
# Title: Billionaire Warren Buffett Sold 56% of Berkshire's Stake in Apple and Is Piling Into Wall Street's Most Prominent Reverse Stock Split of 2024
# Sentiment: positive (Confidence: 0.8287)
# Summary: There's arguably not a billionaire money manager that garners more attention on Wall Street than Berkshire Hathaway's (NYSE: BRK.A)(NYSE: BRK.B) chief, Warren Buffett. The accurately dubbed "Oracle of...
#
# ================================================================================
# Title: Nvidia stock slides amid AI spending slowdown fears, increased competition
# Sentiment: negative (Confidence: 0.9724)
# Summary: Nvidia (NVDA) stock sank more than 2% early Tuesday as investors grew cautious that the AI spending that has fueled its rise could ease or spread to rivals.
#
# ================================================================================
# Title: Stock market today: S&P 500, Nasdaq, Dow slide with rate cuts, sticky inflation in focus
# Sentiment: negative (Confidence: 0.4688)
# Summary: On a day where President-elect Donald Trump rang the opening bell at the New York Stock Exchange, Wall Street failed to build on a furious rally that has picked up steam after his election win. In foc...
#
# ================================================================================
# Title: Mag 7 stocks serve as defensive plays in 2025: Citi strategist
# Sentiment: positive (Confidence: 0.6676)
# Summary: 2024 has been "one big valuation surprise" that has been "dominated by the [Magnificent] Seven megacap growth cohort," Citi head of US equity strategy Scott Chonert tells Julie Hyman and Josh Lipton o...
#
# ================================================================================
# Title: Stock market today: Nasdaq tops 20,000 for first time as Big Tech surge leads stocks higher
# Sentiment: positive (Confidence: 0.9071)
# Summary: US stocks rallied on Wednesday, led by Big Tech, as investors digested another month of sticky inflation data that met economists' expectations and likely pointed to a Federal Reserve interest rate cu...
#
# ================================================================================
# Title: Why Nvidia could be headed for a seismic moment: Another $3 trillion in market cap
# Sentiment: neutral (Confidence: 0.8702)
# Summary: The Nvidia (NVDA) money-making train has only just pulled out of the station.
#
# ================================================================================
# Title: Billionaire Izzy Englander Just Sold Apple, Amazon, and Nvidia but Bought 4 Other "Magnificent Seven" Stocks
# Sentiment: neutral (Confidence: 0.8917)
# Summary: All billionaires don't think alike. For example, Warren Buffett is buying only a few stocks for Berkshire Hathaway's portfolio but has built a massive cash stockpile for the conglomerate. Meanwhile, M...
#
# ================================================================================
# Title: Apple could hit a $4 trillion market cap by early 2025
# Sentiment: neutral (Confidence: 0.9309)
# Summary: Photo: Michael M. Santiago (Getty Images)
#
# ================================================================================
# Title: The iPhone 16 is on shelves, but what is consumer demand indicating?
# Sentiment: neutral (Confidence: 0.6934)
# Summary: The iPhone 16 went on sale Friday, the latest generation of Apple (AAPL) devices already flying over shelves and into consumer hands this morning.
#
# ================================================================================
# Title: Why Apple has little to do with these 2 rocking telecom stocks
# Sentiment: neutral (Confidence: 0.9440)
# Summary: This is The Takeaway from today's Morning Brief, which you can sign up to receive in your inbox every morning along with:
#
# ================================================================================
# Title: Zuckerberg is cashing in on Meta’s record stock price with fresh share sales
# Sentiment: neutral (Confidence: 0.9327)
# Summary: Facebook founder and CEO Mark Zuckerberg sold a fresh batch of Meta Platforms Inc.’s stock last week, according to regulatory filings. - Agence France-Presse/Getty Image
#
# ================================================================================
# Title: Prediction: This Will Be Apple's Next Big Move
# Sentiment: neutral (Confidence: 0.7459)
# Summary: Apple (NASDAQ: AAPL) brought about a revolution in the smartphone market in 2007 when it launched its first-ever iPhone, changing the fortunes of established smartphone companies such as Nokia and Bla...
#
# ================================================================================
# Title: What to expect from Apple's 'It's Glowtime' event
# Sentiment: neutral (Confidence: 0.8718)
# Summary: Apple (AAPL) is gearing up for the "It's Glowtime" event next week, where it is expected to unveil the new iPhone 16. Yahoo Finance Tech Editor Dan Howley joins Catalysts to discuss what investors and...
#
# ================================================================================
# Title: Apple Inc. (AAPL) Set to Launch iOS 18.1 and Apple Intelligence, Shifting from Annual Upgrade Cycle Amid Concerns Over iPhone Demand
# Sentiment: neutral (Confidence: 0.9371)
# Summary: We recently compiled a list of the 35 Trending AI Stocks on Latest News and Analyst Ratings. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against the other tre...
#
# ================================================================================
# Title: If You Bought 1 Share of Apple Stock at Its IPO, Here's How Many Shares You Would Own Now
# Sentiment: neutral (Confidence: 0.6150)
# Summary: Apple (NASDAQ: AAPL) has moved back into the top spot as the largest company in the world by market cap. It's gone through some stunning ups and downs, but if you'd bought shares at the initial public...
#
# ================================================================================
# Title: 39.5% of Warren Buffett's $300.5 Billion Berkshire Hathaway Portfolio Is Invested in These 2 S&P 500 Dividend Stocks
# Sentiment: positive (Confidence: 0.7000)
# Summary: Under the leadership of CEO Warren Buffett, Berkshire Hathaway has become one of history's most successful businesses. The investment conglomerate has a market capitalization of more than $1 trillion,...
#
# ================================================================================
# Title: Why Apple's iPhone 16 just is 'not hitting home' with consumers
# Sentiment: neutral (Confidence: 0.9031)
# Summary: Apple’s (AAPL) newest iPhone lineup is now in stores. However, the release of the iPhone 16 comes without the tech giant’s AI features — dubbed Apple Intelligence — which is slated for an October roll...
#
# ================================================================================
# Title: Apple Launches Largest Overseas R&D Lab in Shenzhen Amid Growing Competition from Huawei
# Sentiment: neutral (Confidence: 0.7003)
# Summary: SHENZHEN, China, Oct. 11, 2024 iPhone-maker Apple (AAPL,Financial) just opened its largest research laboratory outside the U.S. at the Shenzhen Park in Hetao, according to a South China Morning Post r...
#
# ================================================================================
# Title: 34% of the S&P 500's Value Comes From Just 8 Stocks
# Sentiment: neutral (Confidence: 0.9069)
# Summary: The S&P 500 index is a benchmark used to gauge the broader U.S. market. Its 500 large-cap and megacap components come from every sector of the economy, and reflect investing categories from value to g...
#
# ================================================================================
# Title: Prediction: 2 Stocks That Will Be Worth More Than Apple 10 Years From Now
# Sentiment: neutral (Confidence: 0.5085)
# Summary: iPhone maker Apple (NASDAQ: AAPL) has been one of the world's most valuable stocks for a long time.
#
# ================================================================================
# Title: Google's antitrust loss could put billions at risk for Apple
# Sentiment: negative (Confidence: 0.9687)
# Summary: Google (GOOG, GOOGL) suffered a staggering shot to its search and advertising business on Monday as District of Columbia's Judge Amit Mehta ruled in favor of the Department of Justice in its antitrust...
#
# ================================================================================
# Title: 25% of Warren Buffett-Led Berkshire Hathaway's $299 Billion Portfolio Is Invested in Only 1 Stock
# Sentiment: neutral (Confidence: 0.8742)
# Summary: Thanks to his unbelievable track record of compounding capital over many decades as the CEO of Berkshire Hathaway, Warren Buffett is probably the most closely watched investor out there. Everyone can ...
#
# ================================================================================
# Title: Warren Buffett Recently Shunned His Favorite Stock for the First Time Since 2018, and It Could Spell Bad News for Wall Street
# Sentiment: neutral (Confidence: 0.9344)
# Summary: Had you invested $1,000 in the S&P 500 in 1965, it would be worth around $325,053 today. However, had you invested $1,000 in shares of Berkshire Hathaway (NYSE: BRK.A)(NYSE: BRK.B) at the very same ti...
#
# ================================================================================
# Title: Got $5,000? You Might Want to Buy These 3 Unstoppable Stocks
# Sentiment: neutral (Confidence: 0.7268)
# Summary: A $5,000 investment can grow significantly when you put that money into an unstoppable stock and hang on to it for the long term. It's a strategy that can make a lot of sense for long-term investors, ...
#
# ================================================================================
# Title: Magnificent Six will 'dominate' future AI, tech waves: Analyst
# Sentiment: neutral (Confidence: 0.8903)
# Summary: D.A. Davidson has initiated coverage on Meta Platforms (META) — with a Buy rating and $600 per share price target — and Alphabet (GOOG, GOOGL) — with a Neutral rating and $170 per share price target.
#
# ================================================================================
# Title: Warren Buffett Is Selling Apple and Bank of America Stock and Piling Into This High-Yield Investment Instead
# Sentiment: neutral (Confidence: 0.7872)
# Summary: Warren Buffett is one of the most successful investors of all time. He boasts a track record dating back nearly 70 years in which he has produced eye-popping returns for those willing to stick with hi...
#
# ================================================================================
# Title: Big Tech earnings, a Fed meeting, and the July jobs report: What to know this week
# Sentiment: negative (Confidence: 0.9309)
# Summary: The stock market rally is in its most fragile state in months ahead of Wall Street's busiest week of the summer.
#
# ================================================================================
# Title: Best and Worst Holiday Stocks for Options Traders
# Sentiment: neutral (Confidence: 0.9076)
# Summary: It’s the holiday season! We have two consecutive short trading weeks on the way, with Christmas and New Years around the corner. I'm examining the historical data on how stocks tend to perform these w...
#
# ================================================================================
# Title: How AI-powered brain chips could become a $400B industry
# Sentiment: neutral (Confidence: 0.7598)
# Summary: A recent Morgan Stanley report stated that the brain-computer interface (BCI) industry could reach $400B in the US. These AI-fueled chips allow users to control computers with their brain activity and...
#
# ================================================================================
# Title: Warren Buffett Declares Shift: Selling Apple Stock To Invest In This 'Magnificent' Megacap – Here's Why
# Sentiment: positive (Confidence: 0.7707)
# Summary: Warren Buffett, arguably America’s most successful investor, is at it again. His latest moves in the stock market have captured the attention of investors. Under his control since 1965, he has led Ber...
#
# ================================================================================
# Title: Nvidia Dominates Market, BofA Raises EPS Projections and Price Target Amid Strong Free Cash Flow
# Sentiment: positive (Confidence: 0.9370)
# Summary: NEW YORK, Oct. 17, 2024 With a commanding 80% to 85% share in a $400 billion total addressable market, semiconductor giant Nvidia (NVDA, Financials) keeps dominating the business, compelling BofA Secu...
#
# ================================================================================
# Title: The AI stock trade is starting to shift beyond the 'Magnificent 7'
# Sentiment: positive (Confidence: 0.9306)
# Summary: Investor enthusiasm surrounding artificial intelligence has once again driven the "Magnificent Seven" tech stocks to another banner year, with Tesla (TSLA), Meta (META), Amazon (AMZN), Alphabet (GOOG,...
#
# ================================================================================
# Title: Where Will Apple Be in 1 Year?
# Sentiment: positive (Confidence: 0.8589)
# Summary: It's been another wonderful year for Apple (NASDAQ: AAPL) investors. In 2024, shares have produced a total return of 27% (as of Dec. 4). That kind of gain certainly draws the attention of investors lo...
#
# ================================================================================
# Title: 5 Things to Know Before the Stock Market Opens
# Sentiment: neutral (Confidence: 0.9429)
# Summary: Michael Nagle / Bloomberg via Getty Images
#
# ================================================================================
# Title: How to play the Mag 7 stocks in 2025: Portfolio manager
# Sentiment: neutral (Confidence: 0.7565)
# Summary: The "Magnificent Seven" — made up of Nvidia (NVDA), Alphabet (GOOG, GOOGL), Tesla (TSLA), Microsoft (MSFT), Amazon (AMZN), Meta Platforms (META), and Apple (AAPL) — drove major indexes (^DJI, ^IXIC, ^...
#
# ================================================================================
# Title: Stock market today: Dow slides, Alphabet leads Nasdaq higher after new chip reveal
# Sentiment: negative (Confidence: 0.9105)
# Summary: US stocks were mixed on Tuesday as investors trod carefully on the eve of a closely watched consumer inflation report seen as key to the path of interest rates.
#
# ================================================================================
# Title: Intel CEO: We are going through our biggest restructuring in 40 years
# Sentiment: negative (Confidence: 0.9652)
# Summary: Intel (INTC) is leaving investors with a bad case of shock and awe.
#
# ================================================================================
# Title: Here's where Wall Street sees stocks heading after the best 2-year stretch since '97-'98
# Sentiment: negative (Confidence: 0.8013)
# Summary: After two consecutive years of more than 20% gains for the S&P 500 (^GSPC) — an achievement not seen since the late 1990s — Wall Street strategists foresee a slower pace of gains for the benchmark ind...
#
# ================================================================================
# Title: Nvidia stock rebounds after broad market rout as analysts stay bullish on outlook
# Sentiment: positive (Confidence: 0.9264)
# Summary: Nvidia stock (NVDA) jumped as much as 2.7% early Thursday as Wall Street analysts reiterated their Buy ratings on the stock despite concerns about rising competition and the possibility that artificia...
#
# ================================================================================
# Title: Nvidia dominated 2024 big-time. Next year? Plenty of challenges.
# Sentiment: positive (Confidence: 0.7564)
# Summary: Nvidia (NVDA) has had the kind of year most companies can only dream of.
#
# ================================================================================
# Title: Watch These Apple Price Levels After Stock Set a New Record High
# Sentiment: neutral (Confidence: 0.9338)
# Summary: Source: TradingView.com
#
# ================================================================================
# Title: 10 stocks retail investors craved in 2024
# Sentiment: positive (Confidence: 0.9084)
# Summary: Retail investors enjoyed another banner year by sticking with tried-and-true large-cap tech names that raked in big profits and promised advances in artificial intelligence.
#
# ================================================================================
# Title: Nvidia Poised to Hit $250 Share Price by 2025, Analyst Predict
# Sentiment: positive (Confidence: 0.9251)
# Summary: Nvidia (NVDA, Financial) is on an upward trajectory, and market analysts predict the chip giant could one day overtake Apple (AAPL, Financial) in market value. The high demand for Nvidia's latest Blac...
#
# ================================================================================
# Title: Does the 'Magnificent Seven' have more room to run in 2025?
# Sentiment: positive (Confidence: 0.9421)
# Summary: The "Magnificent Seven" tech stocks — Apple (AAPL), Amazon (AMZN), Alphabet (GOOG, GOOGL), Meta Platforms (META), Microsoft (MSFT), Tesla (TSLA), and Nvidia (NVDA) — have continued to lead market gain...
#
# ================================================================================
# Title: Apple's iPhone event is on Monday. Here's what to expect.
# Sentiment: neutral (Confidence: 0.9269)
# Summary: Apple (AAPL) is gearing up for its highly anticipated product launch event on Monday, September 9th. To provide insights into what consumers can expect, CNET Senior Editor Lisa Eadicicco joins Asking ...
#
# ================================================================================
# Title: Why the S&P 500 is poised to rocket 100% in 5 years
# Sentiment: negative (Confidence: 0.8622)
# Summary: The bull run in stocks may have further room for a stampede.
#
# ================================================================================
# Title: Warren Buffett Has Sold $133 Billion Worth of Stock in 2024 So Far, but This Small $550 Million Purchase Is Sending a Big Message to Investors
# Sentiment: neutral (Confidence: 0.6772)
# Summary: Warren Buffett has attracted a lot of attention this year thanks to some very big high-profile stock sales. The Oracle of Omaha has sold a total of $133 billion worth of equities from Berkshire Hathaw...
#
# ================================================================================
# Title: Nvidia stock tumbles from record high on news of possible US chip export cap, ASML's dismal earnings
# Sentiment: negative (Confidence: 0.9744)
# Summary: Nvidia (NVDA) stock sank more than 4% Tuesday, partially reversing its two week-rally and coming down from a record close the day before.
#
# ================================================================================
# Title: San Francisco Fed president Mary Daly: We want to finish the inflation fight
# Sentiment: neutral (Confidence: 0.9380)
# Summary: Listen and subscribe to Opening Bid on Apple Podcasts, Spotify, or wherever you find your favorite podcasts.
#
# ================================================================================
# Title: Apple stock touches intraday high after nod of confidence from Wall Street
# Sentiment: positive (Confidence: 0.9396)
# Summary: Apple (AAPL) stock hit an all-time intraday high Thursday after a nod of confidence in its continued upswing from Wall Street.
#
# ================================================================================
# Title: Jim Cramer on Apple Inc. (AAPL): ‘It Was The Dumb Money That Was Getting Out, Because Warren Buffett Or One Of His Assistants Made Us Nervous’
# Sentiment: neutral (Confidence: 0.9187)
# Summary: We recently published an article titled Jim Cramer's Bold Predictions About These 15 AI Stocks. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against the other ...
#
# ================================================================================
# Title: Why the Dow is suddenly in a historic funk
# Sentiment: negative (Confidence: 0.9644)
# Summary: The Dow Jones Industrial Average (^DJI) is on its worst losing streak in nearly 50 years.
#
# ================================================================================
# Title: What Cruise's self-driving end means for Tesla and Waymo: Morning Brief
# Sentiment: neutral (Confidence: 0.9440)
# Summary: This is The Takeaway from today's Morning Brief, which you can sign up to receive in your inbox every morning along with:
#
# ================================================================================
# Title: Will This Incredibly Cheap Artificial Intelligence (AI) Stock Soar in 2025?
# Sentiment: negative (Confidence: 0.9757)
# Summary: This has turned out to be a forgettable year for Qorvo (NASDAQ: QRVO) investors as shares of the chipmaker are down 38% as of this writing, which is in stark contrast to the 23% gains clocked by the P...
#
# ================================================================================
# Title: Third Point sees room for Apple stock price to climb, letter says
# Sentiment: neutral (Confidence: 0.9289)
# Summary: By Svea Herbst-Bayliss
#
# ================================================================================
# Title: Tesla Stock Leads Magnificent Seven Shares Higher
# Sentiment: neutral (Confidence: 0.9383)
# Summary: Justin Sullivan / Getty Images
#
# ================================================================================
# Title: Stock market today: S&P 500 surges, Dow jumps over 450 points as stocks rebound from worst week of 2024
# Sentiment: positive (Confidence: 0.7764)
# Summary: US stocks rebounded on Monday on the heels of the S&P 500's worst week since early 2023, as inflation came back into focus for investors gauging pressures that could influence the size of interest rat...
#
# ================================================================================
# Title: Stock market news today: Nasdaq futures sink 4%, Dow futures cascade down as global sell-off intensifies
# Sentiment: negative (Confidence: 0.7869)
# Summary: Wall Street's stock sell-off was set to intensify in a major way Monday as concerns mounted over the health of the US economy.
#
# ================================================================================
# Title: Why the 'Magnificent 7' rally could be a 'defensive' move
# Sentiment: neutral (Confidence: 0.5139)
# Summary: December’s market action has been all about a rally from several members of the "Magnificent Seven" tech stocks.
#
# ================================================================================
# Title: Why Taiwan Semiconductor (TSM) Stock Is a Must-Buy on the Dip
# Sentiment: positive (Confidence: 0.6856)
# Summary: Taiwan Semiconductor Manufacturing Co. Ltd. TSM has become a new poster boy on the global artificial intelligence (AI) frenzy. The company is the largest manufacturer of AI-based chipsets for the worl...
#
# ================================================================================
# Title: Drop in Magnificent Seven could drag down U.S. stocks, top fund manager says
# Sentiment: neutral (Confidence: 0.9176)
# Summary: By Saeed Azhar
#
# ================================================================================
# Title: Billionaire Warren Buffett Sold 67% of Berkshire's Stake in Apple and Is Piling Into a Beloved Consumer Brand Whose Stock Has Soared by 7,000% Since Its IPO
# Sentiment: positive (Confidence: 0.9161)
# Summary: There isn't a money manager who commands more attention from the investment community than billionaire Warren Buffett. In his nearly six decades as CEO of Berkshire Hathaway (NYSE: BRK.A)(NYSE: BRK.B)...
#
# ================================================================================
# Title: Magnificent 7 shake-up: Why Wall Street is reassessing Tesla's position and looking toward Netflix
# Sentiment: neutral (Confidence: 0.7964)
# Summary: Tesla (TSLA) has work to do if it wants to remain among tech elites.
#
# ================================================================================
# Title: Stock market today: S&P 500, Nasdaq slip as investors await key inflation data
# Sentiment: negative (Confidence: 0.9327)
# Summary: US stocks wavered on Tuesday as investors trod carefully on the eve of a closely watched consumer inflation report seen as key to the path of interest rates.
#
# ================================================================================
# Title: Morgan Stanley (MS) Stock Forecasts
# Sentiment: neutral (Confidence: 0.8916)
# Summary: Summary
#
# ================================================================================
# Title: Nvidia releases earnings: Takeaways from Mag 7 Q3 results
# Sentiment: positive (Confidence: 0.9267)
# Summary: Nvidia released its third quarter earnings release, with revenue and earnings beating Wall Street expectations. The chipmaker's results close out the "Magnificent Seven" third quarter earnings, as Tes...
#
# ================================================================================
# Title: Why you may want to wait to buy a new iPhone
# Sentiment: neutral (Confidence: 0.7550)
# Summary: Apple (AAPL) is expected to release the latest iPhone in September. While some may be excited to upgrade their phone, they may want to heed caution before buying.
#
# ================================================================================
# Title: Where Will Apple Stock Be in 2025?
# Sentiment: positive (Confidence: 0.9524)
# Summary: Shares of Apple (NASDAQ: AAPL) have delivered returns of 33% in 2024 as of this Dec. 30. They have gained momentum since the company released results for its fiscal 2024 fourth quarter (which ended Se...
#
# ================================================================================
# Title: The Last Time Taiwan Semiconductor Did This, the Stock Doubed in a Year
# Sentiment: positive (Confidence: 0.8346)
# Summary: While a company's past performance is no guarantee of its future results, history is one of the few reasonable things we can use to guide our predictions. Particularly for cyclical companies, it can b...
#
# ================================================================================
# Title: Stock market today: Dow, S&P 500, Nasdaq fall as investors await key inflation data
# Sentiment: negative (Confidence: 0.9673)
# Summary: US stocks fell on Tuesday as investors trod carefully on the eve of a closely watched consumer inflation report seen as key to the path of interest rates.
#
# ================================================================================
# Title: Apple still AI winner despite iPhone 16 reception: Analyst
# Sentiment: neutral (Confidence: 0.6294)
# Summary: Apple's (AAPL) new iPhone 16 has received mixed reception. Antoine Chkaiban, New Street Research technology infrastructure analyst tells Julie Hyman and Josh Lipton on Market Domination to break down ...
#
# ================================================================================
# Title: Why Apple may be due for a stronger-than-usual iPhone update cycle
# Sentiment: neutral (Confidence: 0.9146)
# Summary: Apple (AAPL) launches its iOS 18.2 update today. Some features in the update include ChatGPT integration into Siri and creating your own emojis.
#
# ================================================================================
# Title: Wall Street bullish on Nvidia, Apple: Price targets raised
# Sentiment: positive (Confidence: 0.9516)
# Summary: Nvidia (NVDA) shares are rallying in Monday's trading session following a price target upgrade from Piper Sandler. The investment firm raised its target for the chipmaker to $140 from $120, maintainin...
#
# ================================================================================
# Title: TSMC in talks with Nvidia for AI chip production in Arizona, sources say​
# Sentiment: positive (Confidence: 0.5047)
# Summary: TAIPEI/SINGAPORE (Reuters) - Taiwan Semiconductor Manufacturing Co (TSM, 2330.TW) is in discussions with Nvidia Corp (NVDA) to produce its Blackwell artificial intelligence chips at the contract manuf...
#
# ================================================================================
# Title: AAPL, NVDA, or BABA: Which Tech Giant Could Offer the Highest Upside?
# Sentiment: positive (Confidence: 0.8877)
# Summary: The buzz around generative artificial intelligence (AI) and expectations of falling interest rates are driving several technology stocks higher. While there are concerns about stretched valuations, Wa...
#
# ================================================================================
# Title: Wells Fargo strategist says investors may face 1995 rerun once Fed cuts rates
# Sentiment: neutral (Confidence: 0.9266)
# Summary: Alan Greenspan was the Fed’s chairman during the 1995 rate-cut cycle that may serve as a historical analogue to current conditions. - Saul Loeb/Agence France-Presse/Getty Images
#
# ================================================================================
# Title: DOJ's reported push for Google to sell Chrome is 'political move'
# Sentiment: neutral (Confidence: 0.8086)
# Summary: The US Justice Department (DOJ) is reportedly looking to force Alphabet's Google (GOOG, GOOGL) to divest from its Chrome browser as part of its ongoing antitrust case, according to a Bloomberg report....
#
# ================================================================================
# Title: Apple Stock vs. Tesla Stock: Billionaires Are Buying One and Selling the Other Ahead of 2025
# Sentiment: neutral (Confidence: 0.9454)
# Summary: Apple (NASDAQ: AAPL) and Tesla (NASDAQ: TSLA) are two of the largest and most popular stocks among retail and institutional investors. But a few billionaire-led hedge funds sold Apple and bought Tesla...
#
# ================================================================================
# Title: How does Google's Gemini 2.0 stack up against OpenAI?
# Sentiment: neutral (Confidence: 0.8240)
# Summary: As Apple (AAPL) and Alphabet (GOOG, GOOGL) shares hit record highs on artificial intelligence (AI) announcements, Intelligent Alpha founder and CEO Doug Clinton joins Josh Lipton Asking for a Trend to...
#
# ================================================================================
# Title: Why Apple's iPhone 16 might not be enough to drive sales
# Sentiment: neutral (Confidence: 0.8786)
# Summary: Apple (AAPL) is set to host its iPhone 16 launch event on September 9, with investors eagerly awaiting the unveiling of the next generation of smartphones, Apple Watches, and AirPods. Maxim Group mana...
#
# ================================================================================
# Title: Apple in talks with Tencent, ByteDance to roll out AI features in China, sources say
# Sentiment: neutral (Confidence: 0.9273)
# Summary: By Liam Mo and Brenda Goh
#
# ================================================================================
# Title: Apple investors may want to brace for a sell-off
# Sentiment: negative (Confidence: 0.9626)
# Summary: Apple (AAPL) shares are up about 8% over the past month. But BTIG chief market technician Jonathan Krinsky is warning investors about a potential sell-off in the stock. Krinsky notes that when Apple h...
#
# ================================================================================
# Title: Apple pulls out of OpenAI funding round: WSJ
# Sentiment: neutral (Confidence: 0.8094)
# Summary: Apple (AAPL) recently pulled out of talks to participate in the next round of funding for OpenAI as it seeks to raise $6.5 billion, according to The Wall Street Journal. Nvidia (NVDA) and Microsoft (M...
#
# ================================================================================
# Title: Warren Buffett Sells Apple Stock and Buys a Restaurant Stock Up 3,100% Since Its IPO
# Sentiment: neutral (Confidence: 0.9510)
# Summary: Warren Buffett reportedly manages about 90% of Berkshire Hathaway's (NYSE: BRK.A) (NYSE: BRK.B) equity securities portfolio, while understudies Todd Combs and Ted Weschler handle the rest. The company...
#
# ================================================================================
# Title: Broadcom stock soars as company touts 'massive' AI opportunity
# Sentiment: positive (Confidence: 0.9455)
# Summary: Broadcom stock (AVGO) soared more than 20% Friday as the chipmaker touted its “massive” opportunity in the artificial intelligence market during a quarterly earnings call the prior evening.
#
# ================================================================================
# Title: Apple Inc. (AAPL) Stock Forecasts
# Sentiment: neutral (Confidence: 0.8916)
# Summary: Summary
#
# ================================================================================
# Title: The year Washington tried to humble Big Tech
# Sentiment: neutral (Confidence: 0.7329)
# Summary: The US government long had the nation’s biggest tech giants in its sights, and in 2024, it hit bull's-eye.
#
# ================================================================================
# Title: Apple, Nvidia Supplier TSMC Posts 34% Jump in November Sales
# Sentiment: neutral (Confidence: 0.9519)
# Summary: CFOTO / Future Publishing via Getty Images
#
# ================================================================================
# Title: 66% of Warren Buffett's $301 Billion Portfolio for 2025 Is Invested in These 5 Unstoppable Stocks
# Sentiment: positive (Confidence: 0.7994)
# Summary: For the better part of six decades, Berkshire Hathaway (NYSE: BRK.A)(NYSE: BRK.B) CEO Warren Buffett has been putting on a masterclass in investing for Wall Street. Since ascending to the role as CEO ...
#
# ================================================================================
# Title: Nvidia, Meta Platforms, and Apple Could Help This Unstoppable ETF turn $500 Per Month Into $1 Million
# Sentiment: positive (Confidence: 0.9417)
# Summary: The artificial intelligence (AI) industry is still in its infancy, but investors already witnessed its incredible potential to create value. Since the start of 2023, Nvidia's (NASDAQ: NVDA) market cap...
#
# ================================================================================
# Title: Watch These Apple Stock Price Levels as $4T Market Cap Remains in Striking Distance
# Sentiment: neutral (Confidence: 0.9338)
# Summary: Source: TradingView.com
#
# ================================================================================
# Title: 2 charts show why the stock market sell-off isn't done yet
# Sentiment: neutral (Confidence: 0.5467)
# Summary: The roaring stock market rally of 2024 has finally hit a pause.
#
# ================================================================================
# Title: 3 Stocks That Turned $1,000 Into $1 Million (or More)
# Sentiment: neutral (Confidence: 0.9005)
# Summary: Investors are always looking at potential buying opportunities that could be big winners over time. A good place to find these types of situations is to identify previous winners. This can help you na...
#
# ================================================================================
# Updated sentiment analysis for 96 records
