# %%
import os
from dotenv import load_dotenv
from sec_api import QueryApi, RenderApi
# Load environment variables from .env file
load_dotenv()

# Retrieve the API key from the environment
QUERY_API_KEY = os.getenv("QUERY_API_KEY")
RENDER_API_KEY = os.getenv("RENDER_API_KEY")
# print(f"QUERY_API_KEY: {QUERY_API_KEY}")

# Initialize API clients
queryApi = QueryApi(api_key=QUERY_API_KEY)
renderApi = RenderApi(api_key=RENDER_API_KEY)

query = {
  "query": { "query_string": { 
      "query": "formType:\"10-K\" AND ticker:AAPL", # only 10-Ks
  }},
  "from": "0", # start returning matches from position null, i.e. the first matching filing 
  "size": "1"  # return just one filing
}

response = queryApi.get_filings(query)

# %%
import json 
print(json.dumps(response, indent=2))
# Out:
# {
#   "total": {
#     "value": 32,
#     "relation": "eq"
#   },
#   "query": {
#     "from": 0,
#     "size": 1
#   },
#   "filings": [
#     {
#       "ticker": "AAPL",
#       "formType": "10-K",
#       "accessionNo": "0000320193-24-000123",
#       "cik": "320193",
#       "companyNameLong": "Apple Inc. (Filer)",
#       "companyName": "Apple Inc.",
#       "linkToFilingDetails": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm",
#       "description": "Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]",
#       "linkToTxt": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123.txt",
#       "filedAt": "2024-11-01T06:01:36-04:00",
#       "documentFormatFiles": [
#         {
#           "sequence": "1",
#           "size": "1503780",
#           "documentUrl": "https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm",
#           "description": "10-K",
#           "type": "10-K"
#         },
#         {
#           "sequence": "2",
#           "size": "120785",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit4109282024.htm",
#           "description": "EX-4.1",
#           "type": "EX-4.1"
#         },
#         {
#           "sequence": "3",
#           "size": "56948",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10199282024.htm",
#           "description": "EX-10.19",
#           "type": "EX-10.19"
#         },
#         {
#           "sequence": "4",
#           "size": "74591",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10209282024.htm",
#           "description": "EX-10.20",
#           "type": "EX-10.20"
#         },
#         {
#           "sequence": "5",
#           "size": "60845",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10219282024.htm",
#           "description": "EX-10.21",
#           "type": "EX-10.21"
#         },
#         {
#           "sequence": "6",
#           "size": "75240",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10229282024.htm",
#           "description": "EX-10.22",
#           "type": "EX-10.22"
#         },
#         {
#           "sequence": "7",
#           "size": "44108",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit1919282024.htm",
#           "description": "EX-19.1",
#           "type": "EX-19.1"
#         },
#         {
#           "sequence": "8",
#           "size": "11229",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit21109282024.htm",
#           "description": "EX-21.1",
#           "type": "EX-21.1"
#         },
#         {
#           "sequence": "9",
#           "size": "5018",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit23109282024.htm",
#           "description": "EX-23.1",
#           "type": "EX-23.1"
#         },
#         {
#           "sequence": "10",
#           "size": "10508",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit31109282024.htm",
#           "description": "EX-31.1",
#           "type": "EX-31.1"
#         },
#         {
#           "sequence": "11",
#           "size": "10544",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit31209282024.htm",
#           "description": "EX-31.2",
#           "type": "EX-31.2"
#         },
#         {
#           "sequence": "12",
#           "size": "8357",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit32109282024.htm",
#           "description": "EX-32.1",
#           "type": "EX-32.1"
#         },
#         {
#           "sequence": "13",
#           "size": "13555",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit97109282024.htm",
#           "description": "EX-97.1",
#           "type": "EX-97.1"
#         },
#         {
#           "sequence": "19",
#           "size": "10963",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_g1.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "20",
#           "size": "154498",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_g2.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "21",
#           "size": "2374",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/image_0.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "22",
#           "size": "2563",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/image_01.jpg",
#           "type": "GRAPHIC"
#         },
#         {
#           "sequence": "\u00a0",
#           "size": "9759333",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123.txt",
#           "description": "Complete submission text file",
#           "type": "\u00a0"
#         }
#       ],
#       "periodOfReport": "2024-09-28",
#       "entities": [
#         {
#           "fiscalYearEnd": "0928",
#           "stateOfIncorporation": "CA",
#           "act": "34",
#           "cik": "320193",
#           "fileNo": "001-36743",
#           "irsNo": "942404110",
#           "companyName": "Apple Inc. (Filer)",
#           "type": "10-K",
#           "sic": "3571 Electronic Computers",
#           "filmNo": "241416806",
#           "undefined": "06 Technology)"
#         }
#       ],
#       "id": "de98dc75c98b80c2bbfeb8d07503354b",
#       "seriesAndClassesContractsInformation": [],
#       "linkToHtml": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123-index.htm",
#       "linkToXbrl": "",
#       "dataFiles": [
#         {
#           "sequence": "14",
#           "size": "58200",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928.xsd",
#           "description": "XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT",
#           "type": "EX-101.SCH"
#         },
#         {
#           "sequence": "15",
#           "size": "150261",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_cal.xml",
#           "description": "XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT",
#           "type": "EX-101.CAL"
#         },
#         {
#           "sequence": "16",
#           "size": "232678",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_def.xml",
#           "description": "XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT",
#           "type": "EX-101.DEF"
#         },
#         {
#           "sequence": "17",
#           "size": "779708",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_lab.xml",
#           "description": "XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT",
#           "type": "EX-101.LAB"
#         },
#         {
#           "sequence": "18",
#           "size": "509625",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_pre.xml",
#           "description": "XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT",
#           "type": "EX-101.PRE"
#         },
#         {
#           "sequence": "106",
#           "size": "1355849",
#           "documentUrl": "https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_htm.xml",
#           "description": "EXTRACTED XBRL INSTANCE DOCUMENT",
#           "type": "XML"
#         }
#       ]
#     }
#   ]
# }

# %%
# Base query template
base_query = {
  "query": { 
      "query_string": { 
          "query": "PLACEHOLDER",  # Placeholder to be replaced by the specific query
          "time_zone": "America/New_York"
      } 
  },
  "from": "0",
  "size": "200",
  # sort returned filings by the filedAt key/value
  "sort": [{"filedAt": {"order": "desc"}}]
}

# Open the file we use to store the filing URLs
log_file = open("filing_urls_AAPL.txt", "a")

# Fetch filings for years 2022 and 2021
for year in range(2022, 2025, 1):
    print(f"Starting download for year {year}")
    
    for month in range(1, 13, 1):  # Iterate over each month
        # Construct search query for 10-K filings within the given year-month for AAPL
        universe_query = (
            "formType:(\"10-K\") AND " +
            "filedAt:[{year}-{month:02d}-01 TO {year}-{month:02d}-31] AND " +
            "ticker:AAPL"
        ).format(year=year, month=month)

        # Debugging: Print the query being generated
        print(f"Generated query: {universe_query}")

        # Update query template with specific query string
        base_query["query"]["query_string"]["query"] = universe_query

        # Pagination: Fetch results in batches of 200
        for from_batch in range(0, 400, 200):  # Update pagination start index 
            base_query["from"] = from_batch

            # Debugging: Print the page we're fetching
            print(f"Fetching batch starting at index {from_batch}...")

            try:
                response = queryApi.get_filings(base_query)
                
                # Debugging: Print the raw response
                print(f"Response received: {response}")

                # Stop if no more filings are found
                if len(response["filings"]) == 0:
                    print("No more filings found.")
                    break

                # Extract and store filing URLs
                urls_list = [x["linkToFilingDetails"] for x in response["filings"]]

                # Debugging: Print the number of URLs found in this batch
                print(f"Found {len(urls_list)} URLs in this batch")

                # Transform list of URLs into one string by joining all list elements
                # and add a new-line character between each element.
                urls_string = "\n".join(urls_list) + "\n"
                
                # Write URLs to log file
                log_file.write(urls_string)

            except Exception as e:
                print(f"Error during API request: {e}")
                break

# Close the log file
log_file.close()
print("All AAPL URLs downloaded")
# Out:
# Starting download for year 2022
# Generated query: formType:("10-K") AND filedAt:[2022-01-01 TO 2022-01-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-02-01 TO 2022-02-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-03-01 TO 2022-03-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-04-01 TO 2022-04-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-05-01 TO 2022-05-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-06-01 TO 2022-06-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-07-01 TO 2022-07-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-08-01 TO 2022-08-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-09-01 TO 2022-09-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-10-01 TO 2022-10-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-K', 'accessionNo': '0000320193-22-000108', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm', 'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108.txt', 'filedAt': '2022-10-27T18:01:14-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '2049857', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm', 'description': '10-K', 'type': '10-K'}, {'sequence': '2', 'size': '124132', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit4109242022.htm', 'description': 'EX-4.1', 'type': 'EX-4.1'}, {'sequence': '3', 'size': '11827', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit21109242022.htm', 'description': 'EX-21.1', 'type': 'EX-21.1'}, {'sequence': '4', 'size': '6073', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit23109242022.htm', 'description': 'EX-23.1', 'type': 'EX-23.1'}, {'sequence': '5', 'size': '10609', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit31109242022.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '6', 'size': '10645', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit31209242022.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '7', 'size': '8458', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/a10-kexhibit32109242022.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '13', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '14', 'size': '165673', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_g2.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '10332356', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfReport': '2022-09-24', 'entities': [{'fiscalYearEnd': '0924', 'stateOfIncorporation': 'CA', 'act': '34', 'cik': '320193', 'fileNo': '001-36743', 'irsNo': '942404110', 'companyName': 'Apple Inc. (Filer)', 'type': '10-K', 'sic': '3571 Electronic Computers', 'filmNo': '221338448'}], 'id': '9b58a0b3d70dc9de06bdf3d560b3317a', 'seriesAndClassesContractsInformation': [], 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108-index.htm', 'linkToXbrl': '', 'dataFiles': [{'sequence': '8', 'size': '58100', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.xsd', 'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT', 'type': 'EX-101.SCH'}, {'sequence': '9', 'size': '149987', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_cal.xml', 'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT', 'type': 'EX-101.CAL'}, {'sequence': '10', 'size': '252038', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_def.xml', 'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT', 'type': 'EX-101.DEF'}, {'sequence': '11', 'size': '783084', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_lab.xml', 'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT', 'type': 'EX-101.LAB'}, {'sequence': '12', 'size': '478290' ...
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-11-01 TO 2022-11-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2022-12-01 TO 2022-12-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Starting download for year 2023
# Generated query: formType:("10-K") AND filedAt:[2023-01-01 TO 2023-01-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-02-01 TO 2023-02-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-03-01 TO 2023-03-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-04-01 TO 2023-04-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-05-01 TO 2023-05-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-06-01 TO 2023-06-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-07-01 TO 2023-07-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-08-01 TO 2023-08-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-09-01 TO 2023-09-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-10-01 TO 2023-10-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-11-01 TO 2023-11-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-K', 'accessionNo': '0000320193-23-000106', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930.htm', 'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106.txt', 'filedAt': '2023-11-02T18:08:27-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '1558924', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019323000106/aapl-20230930.htm', 'description': '10-K', 'type': '10-K'}, {'sequence': '2', 'size': '121966', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit4109302023.htm', 'description': 'EX-4.1', 'type': 'EX-4.1'}, {'sequence': '3', 'size': '11229', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit21109302023.htm', 'description': 'EX-21.1', 'type': 'EX-21.1'}, {'sequence': '4', 'size': '5451', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit23109302023.htm', 'description': 'EX-23.1', 'type': 'EX-23.1'}, {'sequence': '5', 'size': '10507', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit31109302023.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '6', 'size': '10543', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit31209302023.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '7', 'size': '8356', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/a10-kexhibit32109302023.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '13', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '14', 'size': '146631', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_g2.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '9569569', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfReport': '2023-09-30', 'entities': [{'fiscalYearEnd': '0930', 'stateOfIncorporation': 'CA', 'act': '34', 'cik': '320193', 'fileNo': '001-36743', 'irsNo': '942404110', 'companyName': 'Apple Inc. (Filer)', 'type': '10-K', 'sic': '3571 Electronic Computers', 'filmNo': '231373899'}], 'id': '0de409aa5047085970060a9efa218f8b', 'seriesAndClassesContractsInformation': [], 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106-index.htm', 'linkToXbrl': '', 'dataFiles': [{'sequence': '8', 'size': '59730', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930.xsd', 'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT', 'type': 'EX-101.SCH'}, {'sequence': '9', 'size': '155393', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_cal.xml', 'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT', 'type': 'EX-101.CAL'}, {'sequence': '10', 'size': '233471', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_def.xml', 'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT', 'type': 'EX-101.DEF'}, {'sequence': '11', 'size': '854271', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_lab.xml', 'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT', 'type': 'EX-101.LAB'}, {'sequence': '12', 'size': '516226', ...
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2023-12-01 TO 2023-12-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Starting download for year 2024
# Generated query: formType:("10-K") AND filedAt:[2024-01-01 TO 2024-01-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-02-01 TO 2024-02-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-03-01 TO 2024-03-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-04-01 TO 2024-04-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-05-01 TO 2024-05-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-06-01 TO 2024-06-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-07-01 TO 2024-07-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-08-01 TO 2024-08-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-09-01 TO 2024-09-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-10-01 TO 2024-10-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-11-01 TO 2024-11-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-K', 'accessionNo': '0000320193-24-000123', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm', 'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123.txt', 'filedAt': '2024-11-01T06:01:36-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '1503780', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm', 'description': '10-K', 'type': '10-K'}, {'sequence': '2', 'size': '120785', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit4109282024.htm', 'description': 'EX-4.1', 'type': 'EX-4.1'}, {'sequence': '3', 'size': '56948', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10199282024.htm', 'description': 'EX-10.19', 'type': 'EX-10.19'}, {'sequence': '4', 'size': '74591', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10209282024.htm', 'description': 'EX-10.20', 'type': 'EX-10.20'}, {'sequence': '5', 'size': '60845', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10219282024.htm', 'description': 'EX-10.21', 'type': 'EX-10.21'}, {'sequence': '6', 'size': '75240', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10229282024.htm', 'description': 'EX-10.22', 'type': 'EX-10.22'}, {'sequence': '7', 'size': '44108', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit1919282024.htm', 'description': 'EX-19.1', 'type': 'EX-19.1'}, {'sequence': '8', 'size': '11229', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit21109282024.htm', 'description': 'EX-21.1', 'type': 'EX-21.1'}, {'sequence': '9', 'size': '5018', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit23109282024.htm', 'description': 'EX-23.1', 'type': 'EX-23.1'}, {'sequence': '10', 'size': '10508', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit31109282024.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '11', 'size': '10544', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit31209282024.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '12', 'size': '8357', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit32109282024.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '13', 'size': '13555', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit97109282024.htm', 'description': 'EX-97.1', 'type': 'EX-97.1'}, {'sequence': '19', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '20', 'size': '154498', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_g2.jpg', 'type': 'GRAPHIC'}, {'sequence': '21', 'size': '2374', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/image_0.jpg', 'type': 'GRAPHIC'}, {'sequence': '22', 'size': '2563', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/image_01.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '9759333', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfR ...
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-K") AND filedAt:[2024-12-01 TO 2024-12-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# All AAPL URLs downloaded

# %%
import multiprocessing

# Download 10-k Filings from Stored URLs
def download_filing(url):
  """
  Downloads a 10-K filing from SEC-API and saves it to the 'filings' folder.
  """
  filing = renderApi.get_filing(url)
  file_name = url.split("/")[-2] + "-" + url.split("/")[-1] # Generate filename
  download_to = "./filings/" + file_name
  
  with open(download_to, "w") as f:
    f.write(filing) # Save filing content to file


# load URLs from log file
def load_urls():
  """
  Loads filing URLs from the log file.
  Returns a list of URLs.
  """
  log_file = open("filing_urls_AAPL.txt", "r")
  urls = log_file.read().split("\n") # convert long string of URLs into a list 
  log_file.close()
  return urls

def download_all_filings():
  """
  Downloads all filings in parallel using multiprocessing.
  """
  print("Start downloading all filings")

  # Create download folder if it doesn't exist
  download_folder = "./filings" 
  if not os.path.isdir(download_folder):
    os.makedirs(download_folder)
    
# Load filing URLs
  urls = load_urls()[1:40] # Downloading the first 40 for testing
  print("{length} filing URLs loaded".format(length=len(urls)))

  # Number of parallel processes for downloading
  number_of_processes = 20

  with multiprocessing.Pool(number_of_processes) as pool:
    pool.map(download_filing, urls)
  
  print("All filings downloaded")

# %%
# Execute download process
download_all_filings()
