# %%
import os
from dotenv import load_dotenv
from sec_api import QueryApi, RenderApi
# Load environment variables from .env file
load_dotenv()

# Retrieve the API key from the environment
QUERY_API_KEY = os.getenv("QUERY_API_KEY")
RENDER_API_KEY = os.getenv("RENDER_API_KEY")
# print(f"QUERY_API_KEY: {QUERY_API_KEY}")

# Initialize API clients
queryApi = QueryApi(api_key=QUERY_API_KEY)
renderApi = RenderApi(api_key=RENDER_API_KEY)

query = {
  "query": { "query_string": { 
      "query": "formType:\"10-Q\" AND ticker:AAPL", # only 10-Ks
  }},
  "from": "0", # start returning matches from position null, i.e. the first matching filing 
  "size": "10"  # return just one filing
}

response = queryApi.get_filings(query)

# %%
# Base query template
base_query = {
  "query": { 
      "query_string": { 
          "query": "PLACEHOLDER",  # Placeholder to be replaced by the specific query
          "time_zone": "America/New_York"
      } 
  },
  "from": "0",
  "size": "200",
  # sort returned filings by the filedAt key/value
  "sort": [{"filedAt": {"order": "desc"}}]
}

# Open the file we use to store the filing URLs
log_file = open("filing_urls_AAPL_10Q.txt", "a")

# Fetch filings for years 2022 and 2021
for year in range(2024, 2025, 1):
    print(f"Starting download for year {year}")
    
    for month in range(1, 13, 1):  # Iterate over each month
        # Construct search query for 10-K filings within the given year-month for AAPL
        universe_query = (
            "formType:(\"10-Q\") AND " +
            "filedAt:[{year}-{month:02d}-01 TO {year}-{month:02d}-31] AND " +
            "ticker:AAPL"
        ).format(year=year, month=month)

        # Debugging: Print the query being generated
        print(f"Generated query: {universe_query}")

        # Update query template with specific query string
        base_query["query"]["query_string"]["query"] = universe_query

        # Pagination: Fetch results in batches of 200
        for from_batch in range(0, 400, 200):  # Update pagination start index 
            base_query["from"] = from_batch

            # Debugging: Print the page we're fetching
            print(f"Fetching batch starting at index {from_batch}...")

            try:
                response = queryApi.get_filings(base_query)
                
                # Debugging: Print the raw response
                print(f"Response received: {response}")

                # Stop if no more filings are found
                if len(response["filings"]) == 0:
                    print("No more filings found.")
                    break

                # Extract and store filing URLs
                urls_list = [x["linkToFilingDetails"] for x in response["filings"]]

                # Debugging: Print the number of URLs found in this batch
                print(f"Found {len(urls_list)} URLs in this batch")

                # Transform list of URLs into one string by joining all list elements
                # and add a new-line character between each element.
                urls_string = "\n".join(urls_list) + "\n"
                
                # Write URLs to log file
                log_file.write(urls_string)

            except Exception as e:
                print(f"Error during API request: {e}")
                break

# Close the log file
log_file.close()
print("All AAPL URLs downloaded")
# Out:
# Starting download for year 2024
# Generated query: formType:("10-Q") AND filedAt:[2024-01-01 TO 2024-01-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-02-01 TO 2024-02-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-Q', 'accessionNo': '0000320193-24-000006', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230.htm', 'description': 'Form 10-Q - Quarterly report [Sections 13 or 15(d)]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006.txt', 'filedAt': '2024-02-01T18:03:38-05:00', 'documentFormatFiles': [{'sequence': '1', 'size': '732173', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000006/aapl-20231230.htm', 'description': '10-Q', 'type': '10-Q'}, {'sequence': '2', 'size': '10529', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit31112302023.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '3', 'size': '10546', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit31212302023.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '4', 'size': '8350', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit32112302023.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '10', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '4984121', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfReport': '2023-12-30', 'entities': [{'fiscalYearEnd': '0928', 'stateOfIncorporation': 'CA', 'act': '34', 'cik': '320193', 'fileNo': '001-36743', 'irsNo': '942404110', 'companyName': 'Apple Inc. (Filer)', 'type': '10-Q', 'sic': '3571 Electronic Computers', 'filmNo': '24588164'}], 'id': '89bd0dd65bb737638cd64a2f597b5155', 'seriesAndClassesContractsInformation': [], 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006-index.htm', 'linkToXbrl': '', 'dataFiles': [{'sequence': '5', 'size': '33359', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230.xsd', 'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT', 'type': 'EX-101.SCH'}, {'sequence': '6', 'size': '79020', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_cal.xml', 'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT', 'type': 'EX-101.CAL'}, {'sequence': '7', 'size': '151992', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_def.xml', 'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT', 'type': 'EX-101.DEF'}, {'sequence': '8', 'size': '534119', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_lab.xml', 'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT', 'type': 'EX-101.LAB'}, {'sequence': '9', 'size': '315230', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_pre.xml', 'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT', 'type': 'EX-101.PRE'}, {'sequence': '67', 'size': '666167', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_htm.xml', 'description': 'EXTRACTED XBRL INSTANCE DOCUMENT', 'type': 'XML'}]}]}
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-03-01 TO 2024-03-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-04-01 TO 2024-04-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-05-01 TO 2024-05-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-Q', 'accessionNo': '0000320193-24-000069', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330.htm', 'description': 'Form 10-Q - Quarterly report [Sections 13 or 15(d)]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069.txt', 'filedAt': '2024-05-02T18:04:25-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '884846', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000069/aapl-20240330.htm', 'description': '10-Q', 'type': '10-Q'}, {'sequence': '2', 'size': '10524', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit31103302024.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '3', 'size': '10541', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit31203302024.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '4', 'size': '8334', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit32103302024.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '10', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '5284139', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfReport': '2024-03-30', 'entities': [{'fiscalYearEnd': '0928', 'stateOfIncorporation': 'CA', 'act': '34', 'cik': '320193', 'fileNo': '001-36743', 'irsNo': '942404110', 'companyName': 'Apple Inc. (Filer)', 'type': '10-Q', 'sic': '3571 Electronic Computers', 'filmNo': '24910117', 'undefined': '06 Technology)'}], 'id': '6c0b495bc8a221cf32387c0123aeee5a', 'seriesAndClassesContractsInformation': [], 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069-index.htm', 'linkToXbrl': '', 'dataFiles': [{'sequence': '5', 'size': '32774', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330.xsd', 'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT', 'type': 'EX-101.SCH'}, {'sequence': '6', 'size': '79020', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_cal.xml', 'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT', 'type': 'EX-101.CAL'}, {'sequence': '7', 'size': '150723', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_def.xml', 'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT', 'type': 'EX-101.DEF'}, {'sequence': '8', 'size': '486518', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_lab.xml', 'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT', 'type': 'EX-101.LAB'}, {'sequence': '9', 'size': '313675', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_pre.xml', 'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT', 'type': 'EX-101.PRE'}, {'sequence': '68', 'size': '780999', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_htm.xml', 'description': 'EXTRACTED XBRL INSTANCE DOCUMENT', 'type': 'XML'}]}]}
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-06-01 TO 2024-06-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-07-01 TO 2024-07-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-08-01 TO 2024-08-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': [{'ticker': 'AAPL', 'formType': '10-Q', 'accessionNo': '0000320193-24-000081', 'cik': '320193', 'companyNameLong': 'Apple Inc. (Filer)', 'companyName': 'Apple Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629.htm', 'description': 'Form 10-Q - Quarterly report [Sections 13 or 15(d)]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081.txt', 'filedAt': '2024-08-01T18:03:34-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '889136', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000081/aapl-20240629.htm', 'description': '10-Q', 'type': '10-Q'}, {'sequence': '2', 'size': '10527', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit31106292024.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '3', 'size': '10544', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit31206292024.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '4', 'size': '8338', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit32106292024.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '10', 'size': '10963', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_g1.jpg', 'type': 'GRAPHIC'}, {'sequence': '\xa0', 'size': '5372771', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfReport': '2024-06-29', 'entities': [{'fiscalYearEnd': '0928', 'stateOfIncorporation': 'CA', 'act': '34', 'cik': '320193', 'fileNo': '001-36743', 'irsNo': '942404110', 'companyName': 'Apple Inc. (Filer)', 'type': '10-Q', 'sic': '3571 Electronic Computers', 'filmNo': '241168182', 'undefined': '06 Technology)'}], 'id': 'cf8f0e4b9c36b768706ac2f63dfceb84', 'seriesAndClassesContractsInformation': [], 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081-index.htm', 'linkToXbrl': '', 'dataFiles': [{'sequence': '5', 'size': '34455', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629.xsd', 'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT', 'type': 'EX-101.SCH'}, {'sequence': '6', 'size': '79020', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_cal.xml', 'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT', 'type': 'EX-101.CAL'}, {'sequence': '7', 'size': '155463', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_def.xml', 'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT', 'type': 'EX-101.DEF'}, {'sequence': '8', 'size': '496189', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_lab.xml', 'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT', 'type': 'EX-101.LAB'}, {'sequence': '9', 'size': '320486', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_pre.xml', 'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT', 'type': 'EX-101.PRE'}, {'sequence': '69', 'size': '786618', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_htm.xml', 'description': 'EXTRACTED XBRL INSTANCE DOCUMENT', 'type': 'XML'}]}]}
# Found 1 URLs in this batch
# Fetching batch starting at index 200...
# Response received: {'total': {'value': 1, 'relation': 'eq'}, 'query': {'from': 200, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-09-01 TO 2024-09-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-10-01 TO 2024-10-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-11-01 TO 2024-11-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# Generated query: formType:("10-Q") AND filedAt:[2024-12-01 TO 2024-12-31] AND ticker:AAPL
# Fetching batch starting at index 0...
# Response received: {'total': {'value': 0, 'relation': 'eq'}, 'query': {'from': 0, 'size': 200}, 'filings': []}
# No more filings found.
# All AAPL URLs downloaded

# %%
import multiprocessing

# Download 10-k Filings from Stored URLs
def download_filing(url):
  """
  Downloads a 10-Q filing from SEC-API and saves it to the 'filings' folder.
  """
  filing = renderApi.get_filing(url)
  file_name = url.split("/")[-2] + "-" + url.split("/")[-1] # Generate filename
  download_to = "./filings/" + file_name
  
  with open(download_to, "w") as f:
    f.write(filing) # Save filing content to file


# load URLs from log file
def load_urls():
  """
  Loads filing URLs from the log file.
  Returns a list of URLs.
  """
  log_file = open("filing_urls_AAPL_10Q.txt", "r")
  urls = log_file.read().split("\n") # convert long string of URLs into a list 
  log_file.close()
  return urls

def download_all_filings():
  """
  Downloads all filings in parallel using multiprocessing.
  """
  print("Start downloading all filings")

  # Create download folder if it doesn't exist
  download_folder = "./filings" 
  if not os.path.isdir(download_folder):
    os.makedirs(download_folder)
    
# Load filing URLs
  urls = load_urls()[1:40] # Downloading the first 40 for testing
  print("{length} filing URLs loaded".format(length=len(urls)))

  # Number of parallel processes for downloading
  number_of_processes = 20

  with multiprocessing.Pool(number_of_processes) as pool:
    pool.map(download_filing, urls)
  
  print("All filings downloaded")

# %%
# Execute download process
download_all_filings()

# %%
from bs4 import BeautifulSoup
# Directory containing .htm filings
FILINGS_DIR = "filings"
EXTRACTED_TEXT_DIR = "apple_filings_text_10Q"

# Ensure output directory exists
if not os.path.exists(EXTRACTED_TEXT_DIR):
    os.makedirs(EXTRACTED_TEXT_DIR)

def extract_text_from_html(file_path):
    """
    Extracts text from an HTML (.htm) filing.
    """
    with open(file_path, "r", encoding="utf-8") as file:
        soup = BeautifulSoup(file, "html.parser")
        
        # Remove script and style elements
        for script in soup(["script", "style"]):
            script.extract()
        
        # Extract clean text
        text = soup.get_text(separator="\n", strip=True)
    return text

# Process all .htm files in the folder
for filename in os.listdir(FILINGS_DIR):
    if filename.endswith(".htm"):
        file_path = os.path.join(FILINGS_DIR, filename)
        extracted_text = extract_text_from_html(file_path)

        # Save extracted text to a .txt file
        output_file_path = os.path.join(EXTRACTED_TEXT_DIR, filename.replace(".htm", ".txt"))
        with open(output_file_path, "w", encoding="utf-8") as output_file:
            output_file.write(extracted_text)

        print(f"Extracted text from {filename} and saved to {output_file_path}")

print("\n All HTML filings processed. Extracted text saved in `filings_text/`.")
# Out:
# Extracted text from 000032019324000123-aapl-20240928.htm and saved to apple_filings_text_10Q/000032019324000123-aapl-20240928.txt
# Extracted text from 000032019324000069-aapl-20240330.htm and saved to apple_filings_text_10Q/000032019324000069-aapl-20240330.txt
# Extracted text from 000032019324000081-aapl-20240629.htm and saved to apple_filings_text_10Q/000032019324000081-aapl-20240629.txt
#
#  All HTML filings processed. Extracted text saved in `filings_text/`.
